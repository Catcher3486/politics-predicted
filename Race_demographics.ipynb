# %%
import pandas as pd
import numpy as np
import sklearn as sk
df = pd.read_csv("US_Election_dataset_v1.csv", sep = ",", header=0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3143 entries, 0 to 3142
# Data columns (total 35 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   Unnamed: 0                                                                 3143 non-null   str
#  1   county                                                                     3143 non-null   str
#  2   state                                                                      3143 non-null   str
#  3   2020 Democrat vote raw                                                     3143 non-null   int64
#  4   2020 Democrat vote %                                                       3143 non-null   float64
#  5   2020 Republican vote raw                                                   3143 non-null   int64
# ...

# %%
df["NH-other"] = df["NH-American Indian and Alaska Native percentage"] + df ["NH-Native Hawaiian and Other Pacific Islander percentage"] + df["NH-Some Other Race percentage"] + df["NH-Two or More Races percentage"]
cols = ["state", "Hispanic or Latino percentage", "NH-White percentage", "NH-Black percentage", "NH-Asian percentage", "NH-other"]
race_demographics_by_state = df[cols]

race_demographics_by_state.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3143 entries, 0 to 3142
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          3143 non-null   str
#  1   Hispanic or Latino percentage  3143 non-null   float64
#  2   NH-White percentage            3143 non-null   float64
#  3   NH-Black percentage            3143 non-null   float64
#  4   NH-Asian percentage            3143 non-null   float64
#  5   NH-other                       3143 non-null   float64
# dtypes: float64(5), str(1)
# memory usage: 147.5 KB

# %%
#vote by race
